# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'house_price.csv', 'Untitled.ipynb']

# %%
import pandas as pd

df = pd.read_csv("house_price.csv")
df.head()
# Out:
#    area  rooms   price
# 0  2104      3  399900
# 1  1600      3  329900
# 2  2400      3  369000
# 3  1416      2  232000
# 4  3000      4  539900

# %%
print(df.shape)
print(df.columns)
# Out:
# (47, 3)
# Index(['area', 'rooms', 'price'], dtype='object')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("house_price.csv")

X = df["area"].values
y = df["price"].values

# %%
X = (X - np.mean(X)) / np.std(X)
y = (y - np.mean(y)) / np.std(y)

# %%
m = 0.0
b = 0.0

learning_rate = 0.01
epochs = 1000

n = len(X)
losses = []

# %%
for epoch in range(epochs):
    
    y_pred = m * X + b

    loss = np.mean((y - y_pred) ** 2)
    losses.append(loss)

    dm = (-2/n) * np.sum(X * (y - y_pred))
    db = (-2/n) * np.sum(y - y_pred)

    m -= learning_rate * dm
    b -= learning_rate * db

# %%
print(f"Final learned equation: y = {m:.4f}x + {b:.4f}")
# Out:
# Final learned equation: y = 0.8550x + -0.0000

# %%
plt.plot(losses)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss vs Epoch")
plt.show()
